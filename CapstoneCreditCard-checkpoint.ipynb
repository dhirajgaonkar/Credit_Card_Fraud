# %% [markdown]
# ### Problem Statement
#
# A credit card is one of the most used financial products to make online purchases and payments. Though the Credit cards can be a convenient way to manage your finances, they can also be risky. Credit card fraud is the unauthorized use of someone else's credit card or credit card information to make purchases or withdraw cash.
#
# It is important that credit card companies are able to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
#
# The dataset contains transactions made by credit cards in September 2013 by European cardholders. This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# We have to build a classification model to predict whether a transaction is fraudulent or not.

# %% [markdown]
# ### Dataset Overview
# The dataset used for this project contains transactions made by credit cards. It includes a highly imbalanced set of observations, where fraudulent transactions are a small fraction of the total.
#
# #### Features:
#
# V1-V28: Principal components obtained via PCA.
#
# Amount: Transaction amount.
#
# Time: Time elapsed from the first transaction.
#
# Class: Fraud status (0 for non-fraud, 1 for fraud).

# %%
pip install pipreqs
# Out:
# Collecting pipreqs
#   Downloading pipreqs-0.5.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting docopt==0.6.2 (from pipreqs)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ipython==8.12.3 (from pipreqs)
#   Downloading ipython-8.12.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting nbconvert<8.0.0,>=7.11.0 (from pipreqs)
#   Downloading nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting yarg==0.1.9 (from pipreqs)
#   Downloading yarg-0.1.9-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting backcall (from ipython==8.12.3->pipreqs)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: decorator in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (5.14.3)
# Requirement already satisfied: colorama in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from ipython==8.12.3->pipreqs) (0.4.6)
# Requirement already satisfied: requests in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from yarg==0.1.9->pipreqs) (2.32.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (5.9.2)
# Requirement already satisfied: packaging in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs) (1.2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jedi>=0.16->ipython==8.12.3->pipreqs) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jupyter-core>=4.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jupyter-core>=4.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (305.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (8.6.0)
# Requirement already satisfied: fastjsonschema in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (4.19.2)
# Requirement already satisfied: wcwidth in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.3->pipreqs) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from beautifulsoup4->nbconvert<8.0.0,>=7.11.0->pipreqs) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from requests->yarg==0.1.9->pipreqs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from requests->yarg==0.1.9->pipreqs) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from requests->yarg==0.1.9->pipreqs) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from requests->yarg==0.1.9->pipreqs) (2024.7.4)
# Requirement already satisfied: executing in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from stack-data->ipython==8.12.3->pipreqs) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from stack-data->ipython==8.12.3->pipreqs) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from stack-data->ipython==8.12.3->pipreqs) (0.2.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\dhiraj.gaonkar\anaconda3a\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs) (6.4.1)
# Downloading pipreqs-0.5.0-py3-none-any.whl (33 kB)
# Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
#    ---------------------------------------- 0.0/798.3 kB ? eta -:--:--
#    -- ------------------------------------- 41.0/798.3 kB 1.9 MB/s eta 0:00:01
#    --- ----------------------------------- 61.4/798.3 kB 812.7 kB/s eta 0:00:01
#    ----- ---------------------------------- 112.6/798.3 kB 1.1 MB/s eta 0:00:01
#    ----- -------------------------------- 122.9/798.3 kB 798.9 kB/s eta 0:00:01
#    ------------ --------------------------- 256.0/798.3 kB 1.1 MB/s eta 0:00:01
#    -------------- ------------------------- 286.7/798.3 kB 1.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 358.4/798.3 kB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 522.2/798.3 kB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 665.6/798.3 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 696.3/798.3 kB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 778.2/798.3 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  788.5/798.3 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 798.3/798.3 kB 1.4 MB/s eta 0:00:00
# Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Downloading nbconvert-7.16.4-py3-none-any.whl (257 kB)
#    ---------------------------------------- 0.0/257.4 kB ? eta -:--:--
#    ---------------------- ----------------- 143.4/257.4 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  256.0/257.4 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 257.4/257.4 kB 2.7 MB/s eta 0:00:00
# Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13773 sha256=88a24843c71a96060306003f4a5384b553d1906087fe2db250fd8f83f056bf98
#   Stored in directory: c:\users\dhiraj.gaonkar\appdata\local\pip\cache\wheels\1a\bf\a1\4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: docopt, backcall, yarg, ipython, nbconvert, pipreqs
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.25.0
#     Uninstalling ipython-8.25.0:
#       Successfully uninstalled ipython-8.25.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 7.10.0
#     Uninstalling nbconvert-7.10.0:
#       Successfully uninstalled nbconvert-7.10.0
# Successfully installed backcall-0.2.0 docopt-0.6.2 ipython-8.12.3 nbconvert-7.16.4 pipreqs-0.5.0 yarg-0.1.9
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.5.1 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 8.12.3 which is incompatible.
# spyder-kernels 2.5.0 requires ipython!=8.17.1,<9,>=8.13.0; python_version > "3.8", but you have ipython 8.12.3 which is incompatible.

# %%
# !pip freeze > requirements.txt

# %%
# !cat requirements.txt
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !nano requirements.txt
# Out:
# 'nano' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
#Reading the dataset
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# Number of columns in Dataset
Columns=df.shape[1]
Columns
# Out:
# 31

# %%
# Number of Rows in Dataset
Rows = df.shape[0]
Rows
# Out:
# 284807

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#                 V10           V11           V12           V13           V14  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.239053e-15  1.673327e-15 -1.247012e-15  8.190001e-16  1.207294e-15
# std    1.088850e+00  1.020713e+00  9.992014e-01  9.952742e-01  9.585956e-01
# min   -2.458826e+01 -4.797473e+00 -1.868371e+01 -5.791881e+00 -1.921433e+01
# 25%   -5.354257e-01 -7.624942e-01 -4.055715e-01 -6.485393e-01 -4.255740e-01
# 50%   -9.291738e-02 -3.275735e-02  1.400326e-01 -1.356806e-02  5.060132e-02
# 75%    4.539234e-01  7.395934e-01  6.182380e-01  6.625050e-01  4.931498e-01
# max    2.374514e+01  1.201891e+01  7.848392e+00  7.126883e+00  1.052677e+01
#
#                 V15           V16           V17           V18           V19  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   4.887456e-15  1.437716e-15 -3.772171e-16  9.564149e-16  1.039917e-15
# std    9.153160e-01  8.762529e-01  8.493371e-01  8.381762e-01  8.140405e-01
# min   -4.498945e+00 -1.412985e+01 -2.516280e+01 -9.498746e+00 -7.213527e+00
# 25%   -5.828843e-01 -4.680368e-01 -4.837483e-01 -4.988498e-01 -4.562989e-01
# 50%    4.807155e-02  6.641332e-02 -6.567575e-02 -3.636312e-03  3.734823e-03
# 75%    6.488208e-01  5.232963e-01  3.996750e-01  5.008067e-01  4.589494e-01
# max    8.877742e+00  1.731511e+01  9.253526e+00  5.041069e+00  5.591971e+00
#
#                 V20           V21           V22           V23           V24  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   6.406204e-16  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    7.709250e-01  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min   -5.449772e+01 -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%   -2.117214e-01 -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%   -6.248109e-02 -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    1.330408e-01  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    3.942090e+01  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %% [markdown]
# # for column in df.columns:
#     # Ensure no negative or zero values before applying log transformation
#     if (df[column] > 0).all():
#         df[column] = np.log(df[column])  # Apply log transformation (natural log)
#     else:
#         # If there's a possibility of zero or negative values, use log1p (log(x + 1))
#         df[column] = np.log1p(df[column])  # Apply log(x + 1)
#
# # Print the transformed dataframe
# print(df)

# %% [markdown]
# df_log = df.applymap(lambda x: np.log(x) if x > 0 else np.nan)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#                 V10           V11           V12           V13           V14  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.239053e-15  1.673327e-15 -1.247012e-15  8.190001e-16  1.207294e-15
# std    1.088850e+00  1.020713e+00  9.992014e-01  9.952742e-01  9.585956e-01
# min   -2.458826e+01 -4.797473e+00 -1.868371e+01 -5.791881e+00 -1.921433e+01
# 25%   -5.354257e-01 -7.624942e-01 -4.055715e-01 -6.485393e-01 -4.255740e-01
# 50%   -9.291738e-02 -3.275735e-02  1.400326e-01 -1.356806e-02  5.060132e-02
# 75%    4.539234e-01  7.395934e-01  6.182380e-01  6.625050e-01  4.931498e-01
# max    2.374514e+01  1.201891e+01  7.848392e+00  7.126883e+00  1.052677e+01
#
#                 V15           V16           V17           V18           V19  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   4.887456e-15  1.437716e-15 -3.772171e-16  9.564149e-16  1.039917e-15
# std    9.153160e-01  8.762529e-01  8.493371e-01  8.381762e-01  8.140405e-01
# min   -4.498945e+00 -1.412985e+01 -2.516280e+01 -9.498746e+00 -7.213527e+00
# 25%   -5.828843e-01 -4.680368e-01 -4.837483e-01 -4.988498e-01 -4.562989e-01
# 50%    4.807155e-02  6.641332e-02 -6.567575e-02 -3.636312e-03  3.734823e-03
# 75%    6.488208e-01  5.232963e-01  3.996750e-01  5.008067e-01  4.589494e-01
# max    8.877742e+00  1.731511e+01  9.253526e+00  5.041069e+00  5.591971e+00
#
#                 V20           V21           V22           V23           V24  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   6.406204e-16  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    7.709250e-01  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min   -5.449772e+01 -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%   -2.117214e-01 -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%   -6.248109e-02 -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    1.330408e-01  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    3.942090e+01  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %% [markdown]
# # Checking the Skewness

# %%
cols = df.columns
cols
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
#Plotting the distribution of the variable (skewness) of all the columns
k = 0
plt.figure(figsize=(17,28))
for i in cols:
    k = k+1
    plt.subplot(6,5,k)
    sns.distplot(df[i])
    plt.title(i + ' '+str(df[i].skew()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       4 for i in cols:
#       5     k = k+1
# ----> 6     plt.subplot(6,5,k)
#       7     sns.distplot(df[i])
#       8     plt.title(i + ' '+str(df[i].skew()))
#
# File ~\anaconda3a\Lib\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
#    1448                  == fig._process_projection_requirements(**kwargs)))):
#
# File ~\anaconda3a\Lib\site-packages\matplotlib\gridspec.py:599, in SubplotSpec._from_subplot_args(figure, args)
#     597 else:
#     598     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 599         raise ValueError(
#     600             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     601             f"not {num!r}"
#     602         )
#     603     i = j = num
#     604 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 30, not 31

# %% [markdown]
# # Correlation
# Correlation is a statistical measure that describes the degree to which two variables change together.
# It quantifies the strength and direction of the linear relationship between two variables.
# A correlation matrix is a table that shows the correlation coefficients between many variables. Each cell in the table represents the correlation between two specific variables

# %%
#Correlation Matrix
correlation_matrix = df.corr()
correlation_matrix.head()
# Out:
#           Time            V1            V2            V3            V4  \
# Time  1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1    0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2   -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3   -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4   -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
#
#                 V5            V6            V7            V8            V9  \
# Time  1.730721e-01 -6.301647e-02  8.471437e-02 -3.694943e-02 -8.660434e-03
# V1    1.812612e-17 -6.506567e-16 -1.005191e-15 -2.433822e-16 -1.513678e-16
# V2    5.157519e-16  2.787346e-16  2.055934e-16 -5.377041e-17  1.978488e-17
# V3   -6.539009e-17  1.627627e-15  4.895305e-16 -1.268779e-15  5.568367e-16
# V4   -1.719944e-15 -7.491959e-16 -4.104503e-16  5.697192e-16  6.923247e-16
#
#                V10           V11           V12           V13           V14  \
# Time  3.061663e-02 -2.476894e-01  1.243481e-01 -6.590202e-02 -9.875682e-02
# V1    7.388135e-17  2.125498e-16  2.053457e-16 -2.425603e-17 -5.020280e-16
# V2   -3.991394e-16  1.975426e-16 -9.568710e-17  6.295388e-16 -1.730566e-16
# V3    1.156587e-15  1.576830e-15  6.310231e-16  2.807652e-16  4.739859e-16
# V4    2.232685e-16  3.459380e-16 -5.625518e-16  1.303306e-16  2.282280e-16
#
#                V15           V16           V17           V18           V19  \
# Time -1.834533e-01  1.190287e-02 -7.329721e-02  9.043813e-02  2.897530e-02
# V1    3.547782e-16  7.212815e-17 -3.879840e-16  3.230206e-17  1.502024e-16
# V2   -4.995814e-17  1.177316e-17 -2.685296e-16  3.284605e-16 -7.118719e-18
# V3    9.068793e-16  8.299445e-16  7.614712e-16  1.509897e-16  3.463522e-16
# V4    1.377649e-16 -9.614528e-16 -2.699612e-16 -5.103644e-16 -3.980557e-16
#
#                V20           V21           V22           V23           V24  \
# Time -5.086602e-02  4.473573e-02  1.440591e-01  5.114236e-02 -1.618187e-02
# V1    4.654551e-16 -2.457409e-16 -4.290944e-16  6.168652e-16 -4.425156e-17
# V2    2.506675e-16 -8.480447e-17  1.526333e-16  1.634231e-16  1.247925e-17
# V3   -9.316409e-16  5.706192e-17 -1.133902e-15 -4.983035e-16  2.686834e-19
# V4   -1.857247e-16 -1.949553e-16 -6.276051e-17  9.164206e-17  1.584638e-16
#
#                V25           V26           V27           V28    Amount  \
# Time -2.330828e-01 -4.140710e-02 -5.134591e-03 -9.412688e-03 -0.010596
# V1   -9.605737e-16 -1.581290e-17  1.198124e-16  2.083082e-15 -0.227709
# V2   -4.478846e-16  2.057310e-16 -4.966953e-16 -5.093836e-16 -0.531409
# V3   -1.104734e-15 -1.238062e-16  1.045747e-15  9.775546e-16 -0.210880
# V4    6.070716e-16 -4.247268e-16  3.977061e-17 -2.761403e-18  0.098732
#
#          Class
# Time -0.012323
# V1   -0.101347
# V2    0.091289
# V3   -0.192961
# V4    0.133447

# %%
plt.figure(figsize=(16,16))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', linewidths=0.5, annot_kws={"size":7})
plt.title('Correlation Matrix of Features')
plt.show()

# %%
#Checking any Missing values 
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # Check for duplicate rows and drop them

# %%
# Checking any duplicated rows
count_of_duplicate_rows = df.duplicated().sum()
print(count_of_duplicate_rows)
# Out:
# 1081

# %%
df = df.drop_duplicates()

# %%
count_of_duplicate_rows_2 = df.duplicated().sum()
print(count_of_duplicate_rows_2)
# Out:
# 0

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (283726, 31)

# %%
# Bar plot for Distribution of target Variables.
plt.figure(figsize=(5,5))
sns.countplot(x='Class', data=df)
plt.title('Fraud and Non Fraudulent Distributions')
plt.show()

# %% [markdown]
# # Train Test Split

# %%
# Putting feature variable in X
X = df.drop('Class',axis=1)

# Putting target variable in y
y = df['Class']

# Splitting data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8 ,test_size=0.2, random_state=100, stratify = y)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %% [markdown]
# # Data Transformation
# # Feature Scaling

# %%
# To scale the features using StandardScaler
def scale_features(X_train, X_test):
    # Initialize the StandardScaler
    scaler = StandardScaler()
    
    # Fit the scaler on the training data and transform the training data
    X_train_scaled = scaler.fit_transform(X_train)
    
    # Transform the test data with the fitted scaler
    X_test_scaled = scaler.transform(X_test)
    
    return X_train_scaled, X_test_scaled

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
X_train.shape
# Out:
# (226980, 30)

# %%
X_test.shape
# Out:
# (56746, 30)

# %% [markdown]
# # Training the model

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve, precision_score, recall_score
import matplotlib.pyplot as plt

def evaluate_model(model, X_train, y_train, X_test, y_test, tuned_model=None):
    # Train the model
    model.fit(X_train, y_train)

    

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    print(f'Accuracy: {accuracy}')
    print("\nClassification Report:\n", classification_report(y_test, y_pred))

    # Precision and Recall (for each class)
    precision = precision_score(y_test, y_pred, average='binary')  # Use 'micro', 'macro', or 'weighted' for multi-class
    recall = recall_score(y_test, y_pred, average='binary')  # Use 'micro', 'macro', or 'weighted' for multi-class
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")

    cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
    print(f'ConfusionMatrix:\n {cm}')

    roc_auc = roc_auc_score(y_test, y_pred)
    print(f"ROC-AUC Score (Imbalanced Data): {roc_auc}\n")

    # Compute the ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])

    # Plot ROC curve
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='b', label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', label='Random Classifier')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve ({model.__class__.__name__})')
    plt.legend(loc='best')
    plt.show()

# %%
# Import necessary models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# Model 1: Logistic Regression
model_1 = LogisticRegression(random_state=42, max_iter=1000)
evaluate_model(model_1, X_train, y_train, X_test, y_test)

# Model 2: Decision Tree Classifier
model_2 = DecisionTreeClassifier(random_state=42)
evaluate_model(model_2, X_train, y_train, X_test, y_test)

# Model 3: Random Forest Classifier
model_3 = RandomForestClassifier(random_state=42)
evaluate_model(model_3, X_train, y_train, X_test, y_test)

# Model 4: Support Vector Classifier (SVC)
model_4 = SVC(probability=True, random_state=42)  # SVC for classification
evaluate_model(model_4, X_train, y_train, X_test, y_test)
# Out:
# Accuracy: 0.9368421052631579
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        88
#            1       0.96      0.92      0.94       102
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
# Precision: 0.9591836734693877
# Recall: 0.9215686274509803
# ConfusionMatrix:
#  [[84  4]
#  [ 8 94]]
# ROC-AUC Score (Imbalanced Data): 0.9380570409982175
# Accuracy: 0.9
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89        88
#            1       0.92      0.89      0.91       102
#
#     accuracy                           0.90       190
#    macro avg       0.90      0.90      0.90       190
# weighted avg       0.90      0.90      0.90       190
#
# Precision: 0.9191919191919192
# Recall: 0.8921568627450981
# ConfusionMatrix:
#  [[80  8]
#  [11 91]]
# ROC-AUC Score (Imbalanced Data): 0.9006238859180035
# Accuracy: 0.9368421052631579
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94        88
#            1       0.99      0.89      0.94       102
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
# Precision: 0.9891304347826086
# Recall: 0.8921568627450981
# ConfusionMatrix:
#  [[87  1]
#  [11 91]]
# ROC-AUC Score (Imbalanced Data): 0.9403966131907309
# Accuracy: 0.5894736842105263
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.60      0.58        88
#            1       0.63      0.58      0.60       102
#
#     accuracy                           0.59       190
#    macro avg       0.59      0.59      0.59       190
# weighted avg       0.59      0.59      0.59       190
#
# Precision: 0.6276595744680851
# Recall: 0.5784313725490197
# ConfusionMatrix:
#  [[53 35]
#  [43 59]]
# ROC-AUC Score (Imbalanced Data): 0.5903520499108735

# %% [markdown]
# # Balancing the dataset
# Oversampling duplicates or creates new synthetic rows in the minority class.
# Undersampling deletes or merges examples in the majority class
# Either undersampling or oversampling can be done when the difference between the count of minority and majority class is less. But if the difference is high oversampling will lead to too much redundant data and undersampling will lead to huge loss of data.
# In our case as the difference between the two classes is high we calculate the average count of the two classes and oversample the minority class to the average value followed by undersampling the majority class to the average value..

# %%
count_0 = y.value_counts()[0]
count_1 = y.value_counts()[1]
print(count_0)
print(count_1)
# Out:
# 473
# 473

# %%
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# Assuming X is the feature matrix and y is the target variable
print(f'Original class distribution: {Counter(y)}')

# Create a random undersampler instance
under_sampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)

# Apply the undersampling to the dataset
X_resampled, y_resampled = under_sampler.fit_resample(X, y)

print(f'Undersampled class distribution: {Counter(y_resampled)}')
# Out:
# Original class distribution: Counter({0: 473, 1: 473})
# Undersampled class distribution: Counter({0: 473, 1: 473})

# %%
X,y =X_resampled, y_resampled
df_resampled = pd.concat([X,y], axis =1)
df_resampled.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 274842  166238.0  0.032432  0.845050  0.161690 -0.798504  0.695579 -0.565116
# 90161    62888.0  1.205443  0.289451  0.741620  0.746450 -0.682445 -1.276868
# 41458    40687.0 -0.275684  1.112403  0.942716 -0.136235  0.427005 -0.504525
# 154410  101450.0  1.802716 -0.304729 -2.092921  0.191727  0.553230 -1.079475
# 75020    55862.0 -2.525869  2.202607  0.633063  0.584094 -0.668050  0.201383
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 274842  0.933765 -0.062716 -0.349653 -0.255274  0.504579  0.951403  0.471139
# 90161   0.136546 -0.284828 -0.106272 -0.092854  0.388966  0.944906  0.974313
# 41458   0.686810 -0.014106 -0.322820 -0.506743 -0.978479 -0.407787  0.167361
# 154410  0.755031 -0.537489  1.236229 -0.280493  1.846121 -1.461476  1.854407
# 75020   0.207289  0.336436  0.751606  1.596623  0.533205  0.604059 -0.516181
#
#              V14       V15       V16       V17       V18       V19       V20  \
# 274842  0.190258 -1.127796  0.194478 -0.828442 -0.184734  0.349512  0.013430
# 90161   0.123923  0.911657  0.113382 -0.271922 -0.806430 -0.327784 -0.043590
# 41458  -0.460737  0.965509  0.631608 -0.291045  0.146259  0.226162  0.130043
# 154410  2.368907 -0.954487 -0.361398  0.127933  0.220937  0.192921  0.061476
# 75020  -0.172642 -0.547824 -0.450105 -0.137874  0.279328  1.228771  0.166092
#
#              V21       V22       V23       V24       V25       V26       V27  \
# 274842 -0.229609 -0.491374  0.001259 -0.400306 -0.451544  0.143434  0.246293
# 90161  -0.208169 -0.589665  0.185183  0.933687  0.168355  0.058053 -0.025197
# 41458  -0.321393 -0.851229 -0.121964 -0.509255 -0.052742  0.124297  0.244629
# 154410  0.078572  0.251564 -0.165849 -0.392507  0.277481  0.121611 -0.135312
# 75020  -0.191501 -0.238654 -0.115595 -0.024809 -0.158276 -0.669323 -1.506852
#
#              V28  Amount  Class
# 274842  0.084199    2.58      0
# 90161   0.027646   11.04      0
# 41458   0.089349    1.78      0
# 154410 -0.068539  157.29      0
# 75020  -0.739474   34.12      0

# %%
df_resampled['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %% [markdown]
# # Resample data

# %%
X_resampled = df_resampled.drop('Class', axis = 1)
y_resampled = df_resampled['Class']

# %% [markdown]
# # Again training the the data after resampling

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Model 1: Logistic Regression
model_1 = LogisticRegression(random_state=42, max_iter=1000)
evaluate_model(model_1, X_train, y_train, X_test, y_test)

# Model 2: Decision Tree Classifier
model_2 = DecisionTreeClassifier(random_state=42)
evaluate_model(model_2, X_train, y_train, X_test, y_test)

# Model 3: Random Forest Classifier
model_3 = RandomForestClassifier(random_state=42)
evaluate_model(model_3, X_train, y_train, X_test, y_test)

# Model 4: Support Vector Machines
model_4 = SVC(probability=True, random_state=42)  # SVC for classification
evaluate_model(model_4, X_train, y_train, X_test, y_test)
# Out:
# Accuracy: 0.9368421052631579
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        88
#            1       0.96      0.92      0.94       102
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
# Precision: 0.9591836734693877
# Recall: 0.9215686274509803
# ConfusionMatrix:
#  [[84  4]
#  [ 8 94]]
# ROC-AUC Score (Imbalanced Data): 0.9380570409982175
# Accuracy: 0.8947368421052632
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89        88
#            1       0.92      0.88      0.90       102
#
#     accuracy                           0.89       190
#    macro avg       0.89      0.90      0.89       190
# weighted avg       0.90      0.89      0.89       190
#
# Precision: 0.9183673469387755
# Recall: 0.8823529411764706
# ConfusionMatrix:
#  [[80  8]
#  [12 90]]
# ROC-AUC Score (Imbalanced Data): 0.8957219251336899
# Accuracy: 0.9315789473684211
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        88
#            1       0.98      0.89      0.93       102
#
#     accuracy                           0.93       190
#    macro avg       0.93      0.93      0.93       190
# weighted avg       0.94      0.93      0.93       190
#
# Precision: 0.978494623655914
# Recall: 0.8921568627450981
# ConfusionMatrix:
#  [[86  2]
#  [11 91]]
# ROC-AUC Score (Imbalanced Data): 0.9347147950089126
# Accuracy: 0.5894736842105263
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.66      0.60        88
#            1       0.64      0.53      0.58       102
#
#     accuracy                           0.59       190
#    macro avg       0.60      0.59      0.59       190
# weighted avg       0.60      0.59      0.59       190
#
# Precision: 0.6428571428571429
# Recall: 0.5294117647058824
# ConfusionMatrix:
#  [[58 30]
#  [48 54]]
# ROC-AUC Score (Imbalanced Data): 0.5942513368983957

# %% [markdown]
# # Hyperparameter Tuning.
# To optimize  models, use GridSearchCV or RandomizedSearchCV to search over a range of hyperparameters. This helps to find the best combination for  models.

# %% [markdown]
# # For Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV

# Example for Logistic Regression
param_grid_lr = {
    'C': [0.1, 1, 10],               # Regularization strength
    'solver': ['liblinear', 'saga'],  # Optimization algorithms
}

grid_search_lr = GridSearchCV(LogisticRegression(random_state=42), param_grid_lr, cv=5, n_jobs=-1)
grid_search_lr.fit(X_train, y_train)

print(f"Best Parameters for Logistic Regression: {grid_search_lr.best_params_}")


grid_search_lr = GridSearchCV(LogisticRegression(random_state=42), param_grid_lr, cv=5, n_jobs=-1)
grid_search_lr.fit(X_train, y_train)
evaluate_model(LogisticRegression(), X_train, y_train, X_test, y_test, tuned_model=grid_search_lr.best_estimator_)
# Out:
# Best Parameters for Logistic Regression: {'C': 0.1, 'solver': 'liblinear'}
# Accuracy: 0.9315789473684211
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93        88
#            1       0.95      0.92      0.94       102
#
#     accuracy                           0.93       190
#    macro avg       0.93      0.93      0.93       190
# weighted avg       0.93      0.93      0.93       190
#
# Precision: 0.9494949494949495
# Recall: 0.9215686274509803
# ConfusionMatrix:
#  [[83  5]
#  [ 8 94]]
# ROC-AUC Score (Imbalanced Data): 0.9323752228163992

# %% [markdown]
# # For Decision Tree

# %%
param_grid_dt = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

grid_search_dt = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid_dt, cv=5)
grid_search_dt.fit(X_train, y_train)
print(f"Best Parameters for Decision Tree: {grid_search_dt.best_params_}")

evaluate_model(DecisionTreeClassifier(), X_train, y_train, X_test, y_test, tuned_model=grid_search_dt.best_estimator_)
# Out:
# Best Parameters for Decision Tree: {'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.8947368421052632
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89        88
#            1       0.91      0.89      0.90       102
#
#     accuracy                           0.89       190
#    macro avg       0.89      0.89      0.89       190
# weighted avg       0.90      0.89      0.89       190
#
# Precision: 0.91
# Recall: 0.8921568627450981
# ConfusionMatrix:
#  [[79  9]
#  [11 91]]
# ROC-AUC Score (Imbalanced Data): 0.8949420677361853

# %% [markdown]
# # For Random Forest Classifier

# %%
# Define the parameter grid for RandomForestClassifier
param_grid_rf = {
    'n_estimators': [50, 100, 200],  # Number of trees in the forest
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4],    # Minimum samples required at a leaf node
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider for splitting
}

# Perform GridSearchCV with RandomForestClassifier
grid_search_rf = GridSearchCV(RandomForestClassifier(random_state=42), param_grid_rf, cv=5, n_jobs=-1)
grid_search_rf.fit(X_train, y_train)

# Use the best model from GridSearchCV for evaluation
evaluate_model(RandomForestClassifier(), X_train, y_train, X_test, y_test, tuned_model=grid_search_rf.best_estimator_)
# Out:
# Accuracy: 0.9315789473684211
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        88
#            1       0.98      0.89      0.93       102
#
#     accuracy                           0.93       190
#    macro avg       0.93      0.93      0.93       190
# weighted avg       0.94      0.93      0.93       190
#
# Precision: 0.978494623655914
# Recall: 0.8921568627450981
# ConfusionMatrix:
#  [[86  2]
#  [11 91]]
# ROC-AUC Score (Imbalanced Data): 0.9347147950089126

# %%
# List of models to evaluate
models = {
    'Logistic Regression': LogisticRegression(random_state=42, max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Support Vector Machines' : SVC(probability=True, random_state=42)
}

# Store accuracy for each model
accuracies = []
Precision_score = []
Recall_score = []
model_names = []

# Loop through models, train and evaluate them
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)
    Precision = precision_score(y_test, y_pred)
    Precision_score.append(Precision)
    Recall = recall_score(y_test, y_pred)
    Recall_score.append(Recall)
    model_names.append(model_name)

    # Display results for each model
    print(f'{model_name} Accuracy: {accuracy}')
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    cm = confusion_matrix(y_test, y_pred)
    print(f'ConfusionMatrix: {cm}  ')

    # Compute ROC-AUC Score
    roc_auc = roc_auc_score(y_test, y_pred)
    print(f"ROC-AUC Score: {roc_auc}\n")

    # Compute and plot ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='b', label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', label='Random Classifier')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve ({model_name})')
    plt.legend(loc='best')
    plt.show()

# Best model selection
best_model_index = Precision_score.index(max(Precision_score))
best_model_name = model_names[best_model_index]

# Plot the accuracy of models
fig, ax = plt.subplots()
ax.bar(model_names, accuracies, color='skyblue', width=0.6)
ax.set_ylabel('Accuracy score')
ax.set_title('Best Model Selection')
plt.xticks(rotation=45)
plt.show()

# Print the best model based on accuracy
print(f"The best model based on accuracy is: {best_model_name}")
# Out:
# Logistic Regression Accuracy: 0.9368421052631579
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        88
#            1       0.96      0.92      0.94       102
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
# ConfusionMatrix: [[84  4]
#  [ 8 94]]
# ROC-AUC Score: 0.9380570409982175
# Decision Tree Accuracy: 0.9
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90        88
#            1       0.93      0.88      0.90       102
#
#     accuracy                           0.90       190
#    macro avg       0.90      0.90      0.90       190
# weighted avg       0.90      0.90      0.90       190
#
# ConfusionMatrix: [[81  7]
#  [12 90]]
# ROC-AUC Score: 0.901403743315508
# Random Forest Accuracy: 0.9315789473684211
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        88
#            1       0.98      0.89      0.93       102
#
#     accuracy                           0.93       190
#    macro avg       0.93      0.93      0.93       190
# weighted avg       0.94      0.93      0.93       190
#
# ConfusionMatrix: [[86  2]
#  [11 91]]
# ROC-AUC Score: 0.9347147950089126
# Support Vector Machines Accuracy: 0.5894736842105263
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.66      0.60        88
#            1       0.64      0.53      0.58       102
#
#     accuracy                           0.59       190
#    macro avg       0.60      0.59      0.59       190
# weighted avg       0.60      0.59      0.59       190
#
# ConfusionMatrix: [[58 30]
#  [48 54]]
# ROC-AUC Score: 0.5942513368983957
# The best model based on accuracy is: Random Forest

# %% [markdown]
# # Model Validation on Random Forest

# %%
y_train_pred = model_3.predict(X_train)
y_pred = model_3.predict(X_test)

# %%
print("Training Accuracy:", accuracy_score(y_train, y_train_pred))
print("Training Precision:", precision_score(y_train, y_train_pred))
# Out:
# Training Accuracy: 1.0
# Training Precision: 1.0

# %%
# Accuracy and Precision on the test set
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Test Precision:", precision_score(y_test, y_pred))
# Out:
# Test Accuracy: 0.9315789473684211
# Test Precision: 0.978494623655914

# %%
# Confusion matrix on the training set
print("Confusion Matrix (Train):\n", confusion_matrix(y_train, y_train_pred))

# Confusion matrix on the test set
print("Confusion Matrix (Test):\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix (Train):
#  [[385   0]
#  [  0 371]]
# Confusion Matrix (Test):
#  [[80  8]
#  [12 90]]

# %%
train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred)

# Accuracy and Precision on the test set
test_accuracy = accuracy_score(y_test, y_pred)
test_precision = precision_score(y_test, y_pred)

# Plotting Accuracy and Precision (Bar plot)
metrics = ['Accuracy', 'Precision']
train_scores = [train_accuracy, train_precision]
test_scores = [test_accuracy, test_precision]

fig, ax = plt.subplots(figsize=(8, 6))

bar_width = 0.35
index = range(len(metrics))

# Plotting bars for training and test scores
ax.bar(index, train_scores, bar_width, label='Train', color='blue')
ax.bar([i + bar_width for i in index], test_scores, bar_width, label='Test', color='orange')

ax.set_xlabel('Metric')
ax.set_ylabel('Score')
ax.set_title('Accuracy and Precision for Training and Test Sets')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(metrics)
ax.legend()

plt.tight_layout()
plt.show()

# Confusion Matrix on the training set
cm_train = confusion_matrix(y_train, y_train_pred)
cm_test = confusion_matrix(y_test, y_pred)

# Plotting Confusion Matrix (Heatmap)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues', ax=ax1, cbar=False)
ax1.set_title('Confusion Matrix (Train)')
ax1.set_xlabel('Predicted')
ax1.set_ylabel('True')

sns.heatmap(cm_test, annot=True, fmt='d', cmap='Blues', ax=ax2, cbar=False)
ax2.set_title('Confusion Matrix (Test)')
ax2.set_xlabel('Predicted')
ax2.set_ylabel('True')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Saving the Model

# %%
# Fit the model with X_train, y_train
Best_model = RandomForestClassifier(random_state=42)
Best_model.fit(X_train, y_train)

# %%
# Save the model
joblib.dump(Best_model, "credit_card_model.pkl")

# %% [markdown]
# # Load the Model

# %%
# Load the model
best_model = joblib.load("credit_card_model.pkl")
